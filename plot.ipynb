# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# # Chapter

# %%
a = 0
print(a)
# Out:
# 0

# %%
import numpy as np
import matplotlib.pyplot as plot

t = np.arange(0,2*np.pi, 0.001)
x = np.sin(2*3*t)

plot.plot(t,x)
plot.show()
